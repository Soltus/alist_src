# %% [markdown]
# ## config.json
#
# ```json
# {
#   "force": false,
#   "site_url": "",
#   "cdn": "",
#   "jwt_secret": "jgfxyfd2ZVbuAhqd",
#   "token_expires_in": 48,
#   "database": {
#     "type": "sqlite3",
#     "host": "",
#     "port": 0,
#     "user": "",
#     "password": "",
#     "name": "",
#     "db_file": "C:\\Users\\Administrator\\AppData\\Roaming\\ci.nn.alist\\data.db",
#     "table_prefix": "x_",
#     "ssl_mode": ""
#   },
#   "scheme": {
#     "address": "0.0.0.0",
#     "http_port": 1234,
#     "https_port": -1,
#     "force_https": false,
#     "cert_file": "",
#     "key_file": "",
#     "unix_file": "",
#     "unix_file_perm": ""
#   },
#   "temp_dir": "C:\\Users\\Administrator\\AppData\\Roaming\\ci.nn.alist\\temp",
#   "bleve_dir": "C:\\Users\\Administrator\\AppData\\Roaming\\ci.nn.alist\\bleve",
#   "dist_dir": "",
#   "log": {
#     "enable": true,
#     "name": "C:\\Users\\Administrator\\AppData\\Roaming\\ci.nn.alist\\log\\log.log",
#     "max_size": 50,
#     "max_backups": 30,
#     "max_age": 28,
#     "compress": false
#   },
#   "delayed_start": 3,
#   "max_connections": 100,
#   "tls_insecure_skip_verify": true,
#   "tasks": {
#     "download": {
#       "workers": 5,
#       "max_retry": 1
#     },
#     "transfer": {
#       "workers": 5,
#       "max_retry": 2
#     },
#     "upload": {
#       "workers": 5,
#       "max_retry": 0
#     },
#     "copy": {
#       "workers": 5,
#       "max_retry": 2
#     }
#   },
#   "cors": {
#     "allow_origins": [
#       "*"
#     ],
#     "allow_methods": [
#       "*"
#     ],
#     "allow_headers": [
#       "*"
#     ]
#   }
# }
# ```
